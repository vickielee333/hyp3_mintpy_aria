# %% [markdown]
# # A. Load HyP3 SBAS Stack into MintPy
#
# *Author: Alex Lewandowski; Alaska Satellite Facility*
#
# **Load your previously downloaded HyP3 SBAS stack into MintPy.**
#
# - Load an SBAS stack from many GeoTiffs into two HDF5 datasets
#   - `geometryGeo.h5`
#   - `ifgramStack.h5`
#
# You only need to perform this step once. You will be able to configure and reconfigure the parameters of your time series analysis without having to reload the data.
#
# This notebook will provide the option to delete your GeoTiffs once they are loaded by MintPy
#
# ---
# ## 0. Import Required Software

# %%
from pathlib import Path
from pprint import pprint
import shutil

import h5py
from ipyfilechooser import FileChooser
from mintpy.cli import plot_network
import opensarlab_lib as osl

# %% [markdown]
# ---
# ## 1. Create a Custom Config File Defining the Paths to the GeoTiffs
#
# **Select the directory holding your MintPy-ready HyP3 data stack and/or MintPy directory from a previously loaded MintPy SBAS stack**
# - Click the `Select` button
# - Navigate to your data directory
# - Click the `Select` button
# - Confirm that the desired path appears in green text
# - Click the `Change` button to alter your selection

# %%
path = Path.home()
fc = FileChooser(path)
display(fc)
# Out:
# FileChooser(path='/home/jovyan', filename='', title='', show_hidden=False, select_desc='Select', change_desc='…

# %% [markdown]
# **Define a project name and create a MintPy directory in which to store files output during our analysis**

# %%
# define the work directory
data_path = Path(fc.selected_path)
print(f"Work directory: {data_path}")

# define the MintPy time-series directory
mint_path = data_path / 'MintPy'
mint_path.mkdir(exist_ok=True)
print(f"MintPy directory: {mint_path}")

# define a project name
proj_name = input("Enter a project name: ")
custom_config_path = mint_path / f'{proj_name}.txt'
print(f"Custom config path: {custom_config_path}")

#create a directory in which to store plots
plot_path = mint_path / "plots"
plot_path.mkdir(exist_ok=True)
# Out:
# Work directory: /home/jovyan/la2_test
# MintPy directory: /home/jovyan/la2_test/MintPy
# Enter a project name:  la2
# Custom config path: /home/jovyan/la2_test/MintPy/la2.txt

# %% [markdown]
# **Define the paths to the GeoTiffs in a custom config**

# %%
con_comp_path = list(data_path.glob('./*/*_conncomp*.tif'))
burst = len(con_comp_path) > 0

config = f"""
mintpy.load.processor        = hyp3
##---------geometry datasets:
mintpy.load.demFile          = {data_path}/*/*_dem*.tif
mintpy.load.incAngleFile     = {data_path}/*/*_lv_theta*.tif
mintpy.load.azAngleFile      = {data_path}/*/*_lv_phi*.tif
mintpy.load.waterMaskFile    = {data_path}/*/*_water_mask*.tif
##---------interferogram datasets:
mintpy.load.unwFile          = {data_path}/*/*_unw_phase*.tif
mintpy.load.corFile          = {data_path}/*/*_corr*.tif
"""

if burst:
    config += f"mintpy.load.connCompFile     = {data_path}/*/*_conncomp*.tif"
    
print(config)
custom_config_path.write_text(config)
# Out:
# mintpy.load.processor        = hyp3
# ##---------geometry datasets:
# mintpy.load.demFile          = /home/jovyan/la2_test/*/*_dem*.tif
# mintpy.load.incAngleFile     = /home/jovyan/la2_test/*/*_lv_theta*.tif
# mintpy.load.azAngleFile      = /home/jovyan/la2_test/*/*_lv_phi*.tif
# mintpy.load.waterMaskFile    = /home/jovyan/la2_test/*/*_water_mask*.tif
# ##---------interferogram datasets:
# mintpy.load.unwFile          = /home/jovyan/la2_test/*/*_unw_phase*.tif
# mintpy.load.corFile          = /home/jovyan/la2_test/*/*_corr*.tif
# 520

# %% [markdown]
# ---
# ## 2. Load the Data with MintPy
#
# The output of the loading step is saved to the `MintPy/inputs` directory:
# - ifgramStack.h5:
# - geometryGeo.h5

# %%
# !smallbaselineApp.py $custom_config_path --work-dir {mint_path} --dostep load_data
# Out:
# MintPy version 1.5.3, date 2023-11-23
# --RUN-at-2024-04-19 18:40:21.436390--
# Current directory: /home/jovyan/test_MintPy_OpenSARLab/LA2
# Run routine processing with smallbaselineApp.py on steps: ['load_data']
# Remaining steps: ['modify_network', 'reference_point', 'quick_overview', 'correct_unwrap_error', 'invert_network', 'correct_LOD', 'correct_SET', 'correct_troposphere', 'deramp', 'correct_topography', 'residual_RMS', 'reference_date', 'velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: la2
# Go to work directory: /home/jovyan/la2_test/MintPy
# copy default template file /home/jovyan/.local/envs/opensarlab_mintpy_recipe_book/lib/python3.9/site-packages/mintpy/defaults/smallbaselineApp.cfg to work directory
# read custom template file: /home/jovyan/la2_test/MintPy/la2.txt
# update default template based on input custom template
#     mintpy.load.processor: auto --> hyp3
#     mintpy.load.unwFile: auto --> /home/jovyan/la2_test/*/*_unw_phase*.tif
#     mintpy.load.corFile: auto --> /home/jovyan/la2_test/*/*_corr*.tif
#     mintpy.load.demFile: auto --> /home/jovyan/la2_test/*/*_dem*.tif
#     mintpy.load.incAngleFile: auto --> /home/jovyan/la2_test/*/*_lv_theta*.tif
#     mintpy.load.azAngleFile: auto --> /home/jovyan/la2_test/*/*_lv_phi*.tif
#     mintpy.load.waterMaskFile: auto --> /home/jovyan/la2_test/*/*_water_mask*.tif
# copy la2.txt              to inputs   directory for backup.
# copy smallbaselineApp.cfg to inputs   directory for backup.
# copy la2.txt              to pic      directory for backup.
# copy smallbaselineApp.cfg to pic      directory for backup.
# read default template file: /home/jovyan/la2_test/MintPy/smallbaselineApp.cfg
#
#
# ******************** step - load_data ********************
#
# load_data.py --template /home/jovyan/la2_test/MintPy/smallbaselineApp.cfg /home/jovyan/la2_test/MintPy/la2.txt --project la2
# processor : hyp3
# SAR platform/sensor : unknown from project name "la2"
# --------------------------------------------------
# prepare metadata files for hyp3 products
# prep_hyp3.py "/home/jovyan/la2_test/*/*_unw_phase*.tif"
# prep_hyp3.py "/home/jovyan/la2_test/*/*_corr*.tif"
# prep_hyp3.py "/home/jovyan/la2_test/*/*_dem*.tif"
# prep_hyp3.py "/home/jovyan/la2_test/*/*_lv_theta*.tif"
# prep_hyp3.py "/home/jovyan/la2_test/*/*_lv_phi*.tif"
# prep_hyp3.py "/home/jovyan/la2_test/*/*_water_mask*.tif"
# --------------------------------------------------
# updateMode : True
# compression: None
# multilook x/ystep: 1/1
# multilook method : nearest
# --------------------------------------------------
# searching geometry files info
# input data files:
# height          : /home/jovyan/la2_test/S1AA_20220101T015007_20220113T015007_VVP012_INT80_G_ueF_25E3/S1AA_20220101T015007_20220113T015007_VVP012_INT80_G_ueF_25E3_dem_clip.tif
# incidenceAngle  : /home/jovyan/la2_test/S1AA_20220101T015007_20220113T015007_VVP012_INT80_G_ueF_25E3/S1AA_20220101T015007_20220113T015007_VVP012_INT80_G_ueF_25E3_lv_theta_clip.tif
# azimuthAngle    : /home/jovyan/la2_test/S1AA_20220101T015007_20220113T015007_VVP012_INT80_G_ueF_25E3/S1AA_20220101T015007_20220113T015007_VVP012_INT80_G_ueF_25E3_lv_phi_clip.tif
# waterMask       : /home/jovyan/la2_test/S1AA_20220101T015007_20220113T015007_VVP012_INT80_G_ueF_25E3/S1AA_20220101T015007_20220113T015007_VVP012_INT80_G_ueF_25E3_water_mask_clip.tif
# --------------------------------------------------
# create HDF5 file /home/jovyan/la2_test/MintPy/inputs/geometryGeo.h5 with w mode
# create dataset /height             of <class 'numpy.float32'>   in size of (1750, 2069) with compression = lzf
# create dataset /incidenceAngle     of <class 'numpy.float32'>   in size of (1750, 2069) with compression = lzf
#     convert incidenceAngle  from Gamma (from horizontal in radian)  to MintPy (from vertical in degree) convention.
# create dataset /azimuthAngle       of <class 'numpy.float32'>   in size of (1750, 2069) with compression = lzf
#     convert azimuthAngle    from Gamma (from east in radian)  to MintPy (from north in degree) convention.
# create dataset /waterMask          of <class 'numpy.bool_'>     in size of (1750, 2069) with compression = lzf
# prepare slantRangeDistance ...
#     geocoded input, use incidenceAngle from file: S1AA_20220101T015007_20220113T015007_VVP012_INT80_G_ueF_25E3_lv_theta_clip.tif
#     convert incidence angle from Gamma to MintPy convention.
# create dataset /slantRangeDistance of <class 'numpy.float32'>   in size of (1750, 2069) with compression = lzf
# Finished writing to /home/jovyan/la2_test/MintPy/inputs/geometryGeo.h5
# --------------------------------------------------
# searching interferogram pairs info
# input data files:
# unwrapPhase     : /home/jovyan/la2_test/*/*_unw_phase*.tif
# coherence       : /home/jovyan/la2_test/*/*_corr*.tif
# number of unwrapPhase     : 121
# number of coherence       : 121
# --------------------------------------------------
# create HDF5 file /home/jovyan/la2_test/MintPy/inputs/ifgramStack.h5 with w mode
# create dataset /unwrapPhase of <class 'numpy.float32'>   in size of (121, 1750, 2069) with compression = None
# [==================================================] 20240208_20240220   13s /     0s
# create dataset /coherence   of <class 'numpy.float32'>   in size of (121, 1750, 2069) with compression = None
# [==================================================] 20240208_20240220   24s /     0s
# create dataset /date        of <class 'numpy.bytes_'>    in size of (121, 2)
# create dataset /bperp       of <class 'numpy.float32'>   in size of (121,)
# create dataset /dropIfgram  of <class 'numpy.bool_'>     in size of (121,)
# add extra metadata: {'PROJECT_NAME': 'la2'}
# Finished writing to /home/jovyan/la2_test/MintPy/inputs/ifgramStack.h5
# --------------------------------------------------
# searching ionosphere pairs info
# input data files:
# WARNING: No data files found for the required dataset: ['unwrapPhase']! Skip loading for ionosphere stack.
# --------------------------------------------------
# searching offset pairs info
# input data files:
# WARNING: No data files found for the required dataset: ['rangeOffset', 'azimuthOffset']! Skip loading for offset stack.
# time used: 00 mins 41.8 secs.
#
# No lookup table (longitude or rangeCoord) found in files.
# Input data seems to be geocoded. Lookup file not needed.
# Loaded dataset are processed by InSAR software: hyp3
# Loaded dataset are in GEO coordinates
# Interferogram Stack: /home/jovyan/la2_test/MintPy/inputs/ifgramStack.h5
# Geometry      File : /home/jovyan/la2_test/MintPy/inputs/geometryGeo.h5
# Lookup Table  File : None
# --------------------------------------------------
# updating metadata based on custom template file la2.txt for file: ifgramStack.h5
# Go back to directory: /home/jovyan/test_MintPy_OpenSARLab/LA2
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 00 mins 42.1 secs

# %%
inputs_path = mint_path/'inputs'
# !ls $inputs_path
# Out:
# geometryGeo.h5	ifgramStack.h5	la2.txt  smallbaselineApp.cfg

# %% [markdown]
# ---
# ## 3. Run the Modify Network Step
#
# - Identifies and excludes interferograms (i.e. affected by coherence phase-unwrapping errors) before the network inversion

# %%
# !smallbaselineApp.py $custom_config_path --work-dir {mint_path} --dostep modify_network
# Out:
# MintPy version 1.5.3, date 2023-11-23
# --RUN-at-2024-04-19 18:41:42.807533--
# Current directory: /home/jovyan/test_MintPy_OpenSARLab/LA2
# Run routine processing with smallbaselineApp.py on steps: ['modify_network']
# Remaining steps: ['reference_point', 'quick_overview', 'correct_unwrap_error', 'invert_network', 'correct_LOD', 'correct_SET', 'correct_troposphere', 'deramp', 'correct_topography', 'residual_RMS', 'reference_date', 'velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: la2
# Go to work directory: /home/jovyan/la2_test/MintPy
# read custom template file: /home/jovyan/la2_test/MintPy/la2.txt
# update default template based on input custom template
# No new option value found, skip updating /home/jovyan/la2_test/MintPy/smallbaselineApp.cfg
# read default template file: /home/jovyan/la2_test/MintPy/smallbaselineApp.cfg
#
#
# ******************** step - modify_network ********************
# Input data seems to be geocoded. Lookup file not needed.
# generate /home/jovyan/la2_test/MintPy/waterMask.h5 from /home/jovyan/la2_test/MintPy/inputs/geometryGeo.h5 for conveniency
# create HDF5 file: /home/jovyan/la2_test/MintPy/waterMask.h5 with w mode
# create dataset /waterMask of bool       in size of (1750, 2069)         with compression=None
# finished writing to /home/jovyan/la2_test/MintPy/waterMask.h5
#
# modify_network.py /home/jovyan/la2_test/MintPy/inputs/ifgramStack.h5 -t /home/jovyan/la2_test/MintPy/smallbaselineApp.cfg
# read options from template file: smallbaselineApp.cfg
# No lookup table (longitude or rangeCoord) found in files.
# No input option found to remove interferogram
# Keep all interferograms by enable --reset option
# --------------------------------------------------
# reset dataset 'dropIfgram' to True for all interferograms for file: /home/jovyan/la2_test/MintPy/inputs/ifgramStack.h5
# All dropIfgram are already True, no need to reset.
#
# plot_network.py /home/jovyan/la2_test/MintPy/inputs/ifgramStack.h5 -t /home/jovyan/la2_test/MintPy/smallbaselineApp.cfg --nodisplay -d coherence -v 0.2 1.0
# read options from template file: smallbaselineApp.cfg
# read temporal/spatial baseline info from file: /home/jovyan/la2_test/MintPy/inputs/ifgramStack.h5
# open ifgramStack file: ifgramStack.h5
# calculating spatial mean of coherence in file /home/jovyan/la2_test/MintPy/inputs/ifgramStack.h5 ...
# read mask from file: waterMask.h5
# [==================================================] 121/121    5s /     0s
# write average value in space into text file: coherenceSpatialAvg.txt
# number of acquisitions: 64
# number of interferograms: 121
# shift all perp baseline by -110.72483825683594 to zero mean for plotting
# --------------------------------------------------
# number of interferograms marked as drop: 0
# number of interferograms marked as keep: 121
# number of acquisitions marked as drop: 0
# save figure to pbaseHistory.pdf
# save figure to coherenceMatrix.pdf
# save figure to coherenceHistory.pdf
# max perpendicular baseline: 367.85 m
# max temporal      baseline: 24.0 days
# showing coherence
# data range: [0.5657, 0.9478]
# display range: [0.2, 1.0]
# save figure to network.pdf
# Go back to directory: /home/jovyan/test_MintPy_OpenSARLab/LA2
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 00 mins 22.5 secs

# %% [markdown]
# ---
# ## 4. Plot the interferogram network
#
# Running **plot_network** gives an overview of the network and the average coherence of the stack. The program creates multiple files as follows:
# - `ifgramStack_coherence_spatialAvg.txt`: Contains interferogram dates, average coherence temporal and spatial baseline separation.
# - `Network.pdf`: Displays the network of interferograms on time-baseline coordinates, colorcoded by avergae coherence of the interferograms.
# - `CoherenceMatrix.pdf` shows the avergae coherence pairs between all available pairs in the stack.

# %%
# %matplotlib inline
with osl.work_dir(mint_path):
    scp_args = f'{inputs_path}/ifgramStack.h5 --cmap-vlist 0.2 0.7 1.0'
    plot_network.main(scp_args.split())
    plots = ['pbaseHistory.pdf', 'coherenceHistory.pdf', 'coherenceMatrix.pdf', 'network.pdf']
    for p in plots:
        if (mint_path/p).exists():
            (mint_path/p).rename(f'{plot_path}/{p}')
# Out:
# read temporal/spatial baseline info from file: /home/jovyan/la2_test/MintPy/inputs/ifgramStack.h5
# open ifgramStack file: ifgramStack.h5
# ['coherenceSpatialAvg.txt'] exists and is newer than ['waterMask.h5'] --> skip.
# coherenceSpatialAvg.txt already exists, read it directly
# number of acquisitions: 64
# number of interferograms: 121
# shift all perp baseline by -110.72483825683594 to zero mean for plotting
# --------------------------------------------------
# number of interferograms marked as drop: 0
# number of interferograms marked as keep: 121
# number of acquisitions marked as drop: 0
# max perpendicular baseline: 367.85 m
# max temporal      baseline: 24.0 days
# showing coherence
# data range: [0.5657, 0.9478]
# display range: (0.2, 1.0)
# showing ...

# %% [markdown]
# ---
# ## 5. Delete Input Data
#
# Once MintPy has loaded the data into HDF5 datasets, you may wish to delete the input data to conserve storage space.
#
# You can adjust configuration parameters and update your analysis without reloading the data from their original source.

# %%
s1_paths = list(data_path.glob('S1*'))
pprint(f'S1 directories: {s1_paths}')
# Out:
# ('S1 directories: '
#  "[PosixPath('/home/jovyan/la2_test/S1AA_20221004T015015_20221028T015016_VVP024_INT80_G_ueF_F542'), "
#  "PosixPath('/home/jovyan/la2_test/S1AA_20220606T015010_20220630T015011_VVP024_INT80_G_ueF_7FBE'), "
#  "PosixPath('/home/jovyan/la2_test/S1AA_20230402T015012_20230426T015012_VVP024_INT80_G_ueF_5AE4'), "
#  "PosixPath('/home/jovyan/la2_test/S1AA_20230613T015015_20230625T015016_VVP012_INT80_G_ueF_AA43'), "
#  "PosixPath('/home/jovyan/la2_test/S1AA_20221016T015016_20221028T015016_VVP012_INT80_G_ueF_175A'), "
#  "PosixPath('/home/jovyan/la2_test/S1AA_20220922T015014_20221016T015016_VVP024_INT80_G_ueF_DF51'), "
#  "PosixPath('/home/jovyan/la2_test/S1AA_20220314T015005_20220326T015006_VVP012_INT80_G_ueF_DFAC'), "
#  "PosixPath('/home/jovyan/la2_test/S1AA_20231210T015019_20231222T015018_VVP012_INT80_G_ueF_11E6'), "
#  "PosixPath('/home/jovyan/la2_test/S1AA_20220513T015008_20220606T015010_VVP024_INT80_G_ueF_8DE0'), "
#  "PosixPath('/home/jovyan/la2_test/S1AA_20230905T015028_20230917T015020_VVP012_INT80_G_ueF_053D'), "
#  "PosixPath('/home/jovyan/la2_test/S1AA_20240127T015017_20240208T015016_VVP012_INT80_G_ueF_A5C1'), "
#  "PosixPath('/home/jovyan/la2_test/S1AA_20230120T015012_20230201T015012_VVP012_INT80_G_ueF_0B7A'), "
#  "PosixPath('/home/jovyan/la2_test/S1AA_20221121T015015_20221215T015014_VVP024_INT80_G_ueF_6C31'), "
#  "PosixPath('/home/jovyan/la2_test/S1AA_20220419T015006_20220513T015008_VVP024_INT80_G_ueF_B4E7'), "
#  "PosixPath('/home/jovyan/la2_test/S1AA_20220805T015013_20220817T015014_VVP012_INT80_G_ueF_3EEC'), "
#  "PosixPath('/home/jovyan/la2_test/S1AA_20230309T015011_20230402T015012_VVP024_INT80_G_ueF_F21C'), "
#  "PosixPath('/home/jovyan/la2_test/S1AA_20220101T015007_20220113T015007_VVP012_INT80_G_ueF_25E3'), "
#  "PosixPath('/home/jovyan/la2_test/S1AA_20231128T015019_20231222T015018_VVP024_INT80_G_ueF_51BF'), "
#  "PosixPath('/home/jovyan/la2_test/S1AA_20220910T015015_20220922T015014_VVP012_INT80_G_ueF_2ACC'), "
#  "PosixPath('/home/jovyan/la2_test/S1AA_20220922T015014_20221004T015015_VVP012_INT80_G_ueF_FA1B'), "
#  "PosixPath('/home/jovyan/la2_test/S1AA_20230508T015013_20230520T015014_VVP012_INT80_G_ueF_5617'), "
#  "PosixPath('/home/jovyan/la2_test/S1AA_20221215T015014_20221227T015013_VVP012_INT80_G_ueF_0CFA'), "
#  "PosixPath('/home/jovyan/la2_test/S1AA_20220724T015012_20220817T015014_VVP024_INT80_G_ueF_87E7'), "
#  "PosixPath('/home/jovyan/la2_test/S1AA_20230601T015014_20230613T015015_VVP012_INT80_G_ueF_E9AF'), "
#  "PosixPath('/home/jovyan/la2_test/S1AA_20230520T015014_20230601T015014_VVP012_INT80_G_ueF_0968'), "
#  "PosixPath('/home/jovyan/la2_test/S1AA_20230321T015011_20230414T015012_VVP024_INT80_G_ueF_6ECB'), "
#  "PosixPath('/home/jovyan/la2_test/S1AA_20220113T015007_20220206T015006_VVP024_INT80_G_ueF_8CA4'), "
#  "PosixPath('/home/jovyan/la2_test/S1AA_20230917T015020_20231011T015020_VVP024_INT80_G_ueF_0E6B'), "
#  "PosixPath('/home/jovyan/la2_test/S1AA_20220218T015005_20220314T015005_VVP024_INT80_G_ueF_7C02'), "
#  "PosixPath('/home/jovyan/la2_test/S1AA_20230905T015028_20230929T015020_VVP024_INT80_G_ueF_B5A2'), "
#  "PosixPath('/home/jovyan/la2_test/S1AA_20220101T015007_20220125T015006_VVP024_INT80_G_ueF_F3BD'), "
#  "PosixPath('/home/jovyan/la2_test/S1AA_20230520T015014_20230613T015015_VVP024_INT80_G_ueF_ADF5'), "
#  "PosixPath('/home/jovyan/la2_test/S1AA_20230414T015012_20230508T015013_VVP024_INT80_G_ueF_382A'), "
#  "PosixPath('/home/jovyan/la2_test/S1AA_20